# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/userbehaviour.csv")

# %%
df.head()
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                 17.0                       634.0            1
# 1    1002                  0.0                        54.0            0
# 2    1003                 37.0                       207.0            0
# 3    1004                 32.0                       445.0            1
# 4    1005                 45.0                       427.0            1
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled
# 2        8                     5                   971    Installed
# 3        6                     2                   799    Installed
# 4        5                     6                  3668    Installed

# %%
df.isnull().sum()
# Out:
# userid                        0
# Average Screen Time           0
# Average Spent on App (INR)    0
# Left Review                   0
# Ratings                       0
# New Password Request          0
# Last Visited Minutes          0
# Status                        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['Status']=lb.fit_transform(df['Status'])

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.metrics import accuracy_score

# %%
x=df.drop(columns=['Status'],axis=1)
y=df["Status"]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
sc=StandardScaler()

# %%
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units = 128 , activation = 'relu' ,
                          input_dim = x_train_scaled.shape[1]),  #input layer
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(units = 64 , activation = 'relu'),    #hidden layer
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(units = 1 , activation = 'sigmoid')   #output layer
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
loss_fn= tf.keras.losses.BinaryCrossentropy()
metrics=['accuracy']

# %%
learning_rate=0.001
momentum=0.9
optimizer = tf.keras.optimizers.SGD(learning_rate = learning_rate ,
                                    momentum = momentum , nesterov = True)

# %%
model.compile(optimizer = optimizer , loss = loss_fn , metrics = metrics)

# %%
model.fit(x_train_scaled ,
         y_train ,
         epochs = 50 ,
          batch_size = 8 ,
          validation_split = 0.1

         )
# Out:
# Epoch 1/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5685 - loss: 0.6599 - val_accuracy: 0.9500 - val_loss: 0.3640
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9226 - loss: 0.3442 - val_accuracy: 0.9875 - val_loss: 0.2065
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9423 - loss: 0.2168 - val_accuracy: 0.9875 - val_loss: 0.1289
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9642 - loss: 0.1534 - val_accuracy: 1.0000 - val_loss: 0.0882
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9822 - loss: 0.1129 - val_accuracy: 1.0000 - val_loss: 0.0659
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9906 - loss: 0.0740 - val_accuracy: 1.0000 - val_loss: 0.0522
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9897 - loss: 0.0708 - val_accuracy: 1.0000 - val_loss: 0.0422
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9888 - loss: 0.0548 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9869 - loss: 0.0445 - val_accuracy: 1.0000 - val_loss: 0.0325
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0438 - val_accuracy: 1.0000 - val_loss: 0.0285
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9958 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0257
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9951 - loss: 0.0366 - val_accuracy: 1.0000 - val_loss: 0.0228
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9964 - loss: 0.0319 - val_accuracy: 1.0000 - val_loss: 0.0205
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 0.0190
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0185
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0251 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9964 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0174
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9941 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9961 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0157
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0157
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9953 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9984 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9948 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9907 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 27/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 28/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9957 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 29/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9943 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 30/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 31/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9954 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 32/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9967 - loss: 0.0126 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 33/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 34/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 35/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9988 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 36/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 37/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9887 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 38/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 39/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9984 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 40/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9971 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 41/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 42/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9950 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 43/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 44/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 45/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 46/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 47/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 48/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9966 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 49/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9999 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 50/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9921 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 0.0086

# %%
loss , accuracy = model.evaluate(x_test_scaled , y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0036

# %%
print("Total Accuracy :" , accuracy)
# Out:
# Total Accuracy : 1.0
